# %% [markdown]
# ## Observations from Data Analysis
# # Dataset Description
# * This dataset belongs to the Education and Academic Performance Analysis domain.The dataset consists of 86 records and 12 columns. Below is an overview of its structure:
#
# * Columns:
# * Total - Total marks obtained by the student (integer).
# * Q1aM4 - Marks obtained in Question 1a (out of 4).
# * Q1bM6 - Marks obtained in Question 1b (out of 6).
# * Q2aM6 - Marks obtained in Question 2a (out of 6).
# * Q2bM4 - Marks obtained in Question 2b (out of 4).
# * Q3aM5 - Marks obtained in Question 3a (out of 5).
# * Q3bM5 - Marks obtained in Question 3b (out of 5).
# * Q4aM3 - Marks obtained in Question 4a (out of 3).
# * Q4bM7 - Marks obtained in Question 4b (out of 7).
# * Q5M10 - Marks obtained in Question 5 (out of 10).
# * Q6aM4 - Marks obtained in Question 6a (out of 4).
# * Q6bM6 - Marks obtained in Question 6b (out of 6).

# %%
import pandas as pd 
df=pd.read_csv("class_marks.csv")
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %%
df.head()
# Out:
#    Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0     37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1     32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2     33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3     24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4     36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
#
#    Q6aM4  Q6bM6
# 0    4.0    6.0
# 1    NaN    NaN
# 2    NaN    NaN
# 3    2.0    NaN
# 4    NaN    NaN

# %% [markdown]
# # Displays first 5 rows of the dataset.

# %%
df.tail()
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 81    4.0    6.0
# 82    3.0    5.0
# 83    4.0    6.0
# 84    NaN    NaN
# 85    1.0    4.0

# %% [markdown]
# # Displays last 5 rows of the dataset.

# %%
df.loc[10:15]
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 10     37    3.0    5.0    6.0    4.0    NaN    NaN    3.0    6.0    NaN
# 11      8    2.0    2.0    NaN    3.0    1.0    NaN    NaN    NaN    NaN
# 12     34    4.0    4.0    5.0    3.0    2.0    2.0    2.0    1.0    9.0
# 13     32    3.0    3.0    6.0    4.0    3.0    5.0    NaN    NaN    9.0
# 14     30    4.0    6.0    6.0    2.0    4.0    5.0    3.0    NaN    NaN
# 15     32    3.0    NaN    2.0    1.0    5.0    5.0    3.0    7.0    NaN
#
#     Q6aM4  Q6bM6
# 10    4.0    6.0
# 11    NaN    NaN
# 12    2.0    2.0
# 13    NaN    NaN
# 14    NaN    NaN
# 15    4.0    6.0

# %% [markdown]
# # Displays the rows with in the range of index

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Total   86 non-null     int64
#  1   Q1aM4   85 non-null     float64
#  2   Q1bM6   73 non-null     float64
#  3   Q2aM6   72 non-null     float64
#  4   Q2bM4   75 non-null     float64
#  5   Q3aM5   52 non-null     float64
#  6   Q3bM5   51 non-null     float64
#  7   Q4aM3   32 non-null     float64
#  8   Q4bM7   26 non-null     float64
#  9   Q5M10   56 non-null     float64
#  10  Q6aM4   33 non-null     float64
#  11  Q6bM6   28 non-null     float64
# dtypes: float64(11), int64(1)
# memory usage: 8.2 KB

# %% [markdown]
# # provides the infomation about the dataset

# %%
df.isnull()
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0   False  False  False  False  False  False  False   True  False  False
# 1   False  False  False  False  False   True   True  False  False  False
# 2   False  False  False  False  False  False  False   True   True  False
# 3   False  False  False  False  False  False  False   True   True   True
# 4   False  False  False  False  False  False  False   True   True  False
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81  False  False  False  False  False  False  False   True   True   True
# 82  False  False  False  False  False   True   True   True   True  False
# 83  False  False  False  False  False   True   True   True   True  False
# 84  False  False   True  False  False  False  False   True   True  False
# 85  False  False  False   True   True   True   True  False  False  False
#
#     Q6aM4  Q6bM6
# 0   False  False
# 1    True   True
# 2    True   True
# 3   False   True
# ...

# %% [markdown]
# # Checks weather the values are null or not

# %%
df.isnull().sum()
# Out:
# Total     0
# Q1aM4     1
# Q1bM6    13
# Q2aM6    14
# Q2bM4    11
# Q3aM5    34
# Q3bM5    35
# Q4aM3    54
# Q4bM7    60
# Q5M10    30
# Q6aM4    53
# Q6bM6    58
# dtype: int64

# %%
df = df.fillna(df.mean())  # Assign the returned DataFrame to df

# %%
df
# Out:
#     Total  Q1aM4     Q1bM6     Q2aM6  Q2bM4     Q3aM5     Q3bM5    Q4aM3  \
# 0      37    4.0  5.000000  6.000000    4.0  2.000000  1.000000  2.46875
# 1      32    4.0  3.000000  4.000000    3.0  4.173077  4.098039  3.00000
# 2      33    4.0  5.000000  5.000000    1.0  5.000000  5.000000  2.46875
# 3      24    4.0  6.000000  6.000000    3.0  2.000000  2.000000  2.46875
# 4      36    3.0  6.000000  4.000000    4.0  5.000000  4.000000  2.46875
# ..    ...    ...       ...       ...    ...       ...       ...      ...
# 81     32    3.0  6.000000  3.000000    4.0  5.000000  3.000000  2.46875
# 82     27    2.0  2.000000  5.000000    3.0  4.173077  4.098039  2.46875
# 83     37    4.0  6.000000  6.000000    2.0  4.173077  4.098039  2.46875
# 84     28    4.0  4.972603  5.000000    4.0  5.000000  4.000000  2.46875
# 85     29    4.0  6.000000  5.291667    3.2  4.173077  4.098039  3.00000
#
#        Q4bM7  Q5M10     Q6aM4     Q6bM6
# 0   5.000000    8.0  4.000000  6.000000
# ...

# %%
df.isnull().sum()
# Out:
# Total    0
# Q1aM4    0
# Q1bM6    0
# Q2aM6    0
# Q2bM4    0
# Q3aM5    0
# Q3bM5    0
# Q4aM3    0
# Q4bM7    0
# Q5M10    0
# Q6aM4    0
# Q6bM6    0
# dtype: int64

# %% [markdown]
# # Total number of null values present in each question

# %%
df.Total.mean()
# Out:
# 29.36046511627907

# %% [markdown]
# Mean value of Total

# %%
df.Total.median()
# Out:
# 31.0

# %% [markdown]
# Median value of total

# %%
df[df.Total>35]
# Out:
#     Total     Q1aM4     Q1bM6     Q2aM6  Q2bM4     Q3aM5     Q3bM5    Q4aM3  \
# 0      37  4.000000  5.000000  6.000000    4.0  2.000000  1.000000  2.46875
# 4      36  3.000000  6.000000  4.000000    4.0  5.000000  4.000000  2.46875
# 10     37  3.000000  5.000000  6.000000    4.0  4.173077  4.098039  3.00000
# 17     36  3.000000  4.000000  6.000000    4.0  4.173077  4.098039  2.46875
# 26     39  4.000000  6.000000  6.000000    3.0  4.000000  4.098039  2.46875
# 28     38  2.000000  6.000000  6.000000    4.0  5.000000  5.000000  2.46875
# 33     40  3.141176  4.972603  6.000000    4.0  5.000000  5.000000  3.00000
# 36     37  2.000000  4.972603  6.000000    4.0  5.000000  5.000000  2.46875
# 42     38  4.000000  6.000000  6.000000    4.0  5.000000  5.000000  3.00000
# 44     36  3.000000  6.000000  6.000000    2.0  4.173077  4.098039  2.00000
# 46     36  4.000000  5.000000  6.000000    4.0  5.000000  5.000000  2.46875
# ...

# %% [markdown]
# # Displays the dataset where the total value is greater than 35

# %%
df["Q1"]=df["Q1aM4"]+df["Q1bM6"]
df["Q2"]=df["Q2aM6"]+df["Q2bM4"]
df["Q3"]=df["Q3aM5"]+df["Q3bM5"]
df["Q4"]=df["Q4aM3"]+df["Q4bM7"]
df["Q6"]=df["Q6aM4"]+df["Q6bM6"]
df
# Out:
#     Total  Q1aM4     Q1bM6     Q2aM6  Q2bM4     Q3aM5     Q3bM5    Q4aM3  \
# 0      37    4.0  5.000000  6.000000    4.0  2.000000  1.000000  2.46875
# 1      32    4.0  3.000000  4.000000    3.0  4.173077  4.098039  3.00000
# 2      33    4.0  5.000000  5.000000    1.0  5.000000  5.000000  2.46875
# 3      24    4.0  6.000000  6.000000    3.0  2.000000  2.000000  2.46875
# 4      36    3.0  6.000000  4.000000    4.0  5.000000  4.000000  2.46875
# ..    ...    ...       ...       ...    ...       ...       ...      ...
# 81     32    3.0  6.000000  3.000000    4.0  5.000000  3.000000  2.46875
# 82     27    2.0  2.000000  5.000000    3.0  4.173077  4.098039  2.46875
# 83     37    4.0  6.000000  6.000000    2.0  4.173077  4.098039  2.46875
# 84     28    4.0  4.972603  5.000000    4.0  5.000000  4.000000  2.46875
# 85     29    4.0  6.000000  5.291667    3.2  4.173077  4.098039  3.00000
#
#        Q4bM7  Q5M10     Q6aM4     Q6bM6         Q1         Q2         Q3  \
# ...

# %% [markdown]
#  # New Columns Q1,Q2,Q3,Q4,Q6 are created above to do analysis.

# %%
df.drop("Q1aM4",axis=1,inplace=True)
df.drop("Q1bM6",axis=1,inplace=True)
df.drop("Q2aM6",axis=1,inplace=True)
df.drop("Q2bM4",axis=1,inplace=True)
df.drop("Q3aM5",axis=1,inplace=True)
df.drop("Q3bM5",axis=1,inplace=True)
df.drop("Q4aM3",axis=1,inplace=True)
df.drop("Q4bM7",axis=1,inplace=True)
df.drop("Q6aM4",axis=1,inplace=True)
df.drop("Q6bM6",axis=1,inplace=True)
df
# Out:
#     Total  Q5M10         Q1         Q2         Q3        Q4         Q6
# 0      37    8.0   9.000000  10.000000   3.000000  7.468750  10.000000
# 1      32    9.0   7.000000   7.000000   8.271116  9.000000   8.449134
# 2      33    8.0   9.000000   6.000000  10.000000  7.353365   8.449134
# 3      24    8.0  10.000000   9.000000   4.000000  7.353365   6.964286
# 4      36   10.0   9.000000   8.000000   9.000000  7.353365   8.449134
# ..    ...    ...        ...        ...        ...       ...        ...
# 81     32    8.0   9.000000   7.000000   8.000000  7.353365  10.000000
# 82     27    7.0   4.000000   8.000000   8.271116  7.353365   8.000000
# 83     37    9.0  10.000000   8.000000   8.271116  7.353365  10.000000
# 84     28    6.0   8.972603   9.000000   9.000000  7.353365   8.449134
# 85     29    7.0  10.000000   8.491667   8.271116  8.000000   5.000000
#
# [86 rows x 7 columns]

# %% [markdown]
# # Deleting all the previous columns in order to analyze the data.

# %%
df.rename(columns={'Q5M10':'Q5'},inplace=True)
df
# Out:
#     Total    Q5         Q1         Q2         Q3        Q4         Q6
# 0      37   8.0   9.000000  10.000000   3.000000  7.468750  10.000000
# 1      32   9.0   7.000000   7.000000   8.271116  9.000000   8.449134
# 2      33   8.0   9.000000   6.000000  10.000000  7.353365   8.449134
# 3      24   8.0  10.000000   9.000000   4.000000  7.353365   6.964286
# 4      36  10.0   9.000000   8.000000   9.000000  7.353365   8.449134
# ..    ...   ...        ...        ...        ...       ...        ...
# 81     32   8.0   9.000000   7.000000   8.000000  7.353365  10.000000
# 82     27   7.0   4.000000   8.000000   8.271116  7.353365   8.000000
# 83     37   9.0  10.000000   8.000000   8.271116  7.353365  10.000000
# 84     28   6.0   8.972603   9.000000   9.000000  7.353365   8.449134
# 85     29   7.0  10.000000   8.491667   8.271116  8.000000   5.000000
#
# [86 rows x 7 columns]

# %% [markdown]
# # Renaming the Q5M10 as Q5

# %%
df.sort_values(["Total","Q1","Q2","Q3","Q4","Q5","Q6"], ascending=True)
# Out:
#     Total    Q5         Q1         Q2         Q3         Q4         Q6
# 69      3   8.0   5.972603   4.200000   8.271116   5.884615   8.449134
# 11      8   8.0   4.000000   8.291667   5.098039   7.353365   8.449134
# 23      9   8.0   7.000000   8.491667   8.271116   7.353365   2.000000
# 22     14   8.0   8.000000   7.000000   8.271116   7.353365   8.449134
# 76     17   8.0   5.000000   6.000000   6.000000   7.353365   8.449134
# ..    ...   ...        ...        ...        ...        ...        ...
# 51     40  10.0   4.972603  10.000000   8.271116  10.000000   8.449134
# 33     40   8.0   8.113779  10.000000  10.000000  10.000000  10.000000
# 73     40  10.0  10.000000   8.491667  10.000000   7.884615  10.000000
# 53     40  10.0  10.000000  10.000000  10.000000   7.353365   8.449134
# 65     40  10.0  10.000000  10.000000  10.000000   7.353365   8.449134
#
# [86 rows x 7 columns]

# %% [markdown]
# # All columns values are sorted in ascending order above.

# %%
import matplotlib.pyplot as plt
plt.hist(df['Q1'],color='orange',edgecolor='blue',bins=10)
plt.xlabel("Marks scored in Q1")
plt.ylabel("No.of students ")
plt.title("Histogram of Q1")
# Out:
# Text(0.5, 1.0, 'Histogram of Q1')

# %% [markdown]
# # Most of the students scored between 8 and 10 marks, with fewer students scoring at the lower end (4 to 6 marks).

# %%
print(df['Q1'].value_counts())
# Out:
# Q1
# 10.000000    19
# 8.000000     17
# 9.000000     16
# 7.000000      9
# 6.000000      5
# 8.972603      5
# 5.000000      5
# 7.972603      3
# 4.000000      2
# 6.972603      2
# 8.113779      1
# 4.972603      1
# 5.972603      1
# Name: count, dtype: int64

# %%
plt.hist(df["Q2"],color='pink',bins=7,edgecolor='yellow')
plt.xlabel("Marks scored in Q2")
plt.ylabel("No.of students")
plt.title("Histogram of Q2")
# Out:
# Text(0.5, 1.0, 'Histogram of Q2')

# %% [markdown]
# # most students scored between 8 and 10 marks, with a maximun score of 10 marks, showing a strong overall performance in Q2.

# %%
print(df['Q2'].value_counts())
# Out:
# Q2
# 10.000000    34
# 8.000000     13
# 7.000000     10
# 8.491667      9
# 9.000000      6
# 6.000000      3
# 8.291667      2
# 4.000000      2
# 7.291667      1
# 8.200000      1
# 3.000000      1
# 6.291667      1
# 9.291667      1
# 5.000000      1
# 4.200000      1
# Name: count, dtype: int64

# %%
plt.hist(df["Q3"],color='green',bins=10,edgecolor='red')
plt.xlabel("Marks scored in Q3")
plt.ylabel("No.of students")
plt.title("Histogram of Q3")
# Out:
# Text(0.5, 1.0, 'Histogram of Q3')

# %% [markdown]
# # The majority of students scored 10 marks in Q3.This means that Q3 was relatively easier.

# %%
print(df['Q3'].value_counts())
# Out:
# Q3
# 8.271116     30
# 10.000000    27
# 7.000000      5
# 8.000000      4
# 9.000000      3
# 5.000000      2
# 4.000000      2
# 9.173077      2
# 6.000000      2
# 6.098039      2
# 3.000000      1
# 5.173077      1
# 6.173077      1
# 9.098039      1
# 8.098039      1
# 5.098039      1
# 2.000000      1
# Name: count, dtype: int64

# %%
plt.hist(df["Q4"],color='red',bins=9,edgecolor='green')
plt.xlabel("Marks scored in Q4")
plt.ylabel("No.of students")
plt.title("Histogram of Q4")
# Out:
# Text(0.5, 1.0, 'Histogram of Q4')

# %% [markdown]
# # Most of the students scored 10 marks, which is the highest score. A smaller number of students scored lower marks, like 2, 3, 4, 6, 7, and 8. This means many students did really well in Q4, with fewer students scoring lower marks.

# %%
print(df['Q4'].value_counts())
# Out:
# Q4
# 7.353365     50
# 10.000000     7
# 9.000000      5
# 7.884615      4
# 6.884615      3
# 3.000000      3
# 6.000000      3
# 5.884615      3
# 5.468750      2
# 8.000000      2
# 7.468750      1
# 9.468750      1
# 2.000000      1
# 7.000000      1
# Name: count, dtype: int64

# %%
plt.hist(df["Q5"],color='purple',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q5")
plt.ylabel("No.of students")
plt.title("Histogram of Q5")
# Out:
# Text(0.5, 1.0, 'Histogram of Q5')

# %% [markdown]
# # Majority students scored between 7 and 10 marks, with 10 marks as maximum marks scored & fewer students scored at the lower end 4 to 6 marks with 4 marks as least marks scored.

# %%
print(df['Q5'].value_counts())
# Out:
# Q5
# 8.0     40
# 10.0    15
# 7.0     12
# 9.0      9
# 6.0      5
# 5.0      3
# 4.0      2
# Name: count, dtype: int64

# %%
plt.hist(df["Q6"],color='brown',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q6")
plt.ylabel("No.of students")
plt.title("Histogram of Q6")
# Out:
# Text(0.5, 1.0, 'Histogram of Q6')

# %% [markdown]
# # Majority of the students scored 10 marks in Q6, which is the highest score. Only a few students scored lower marks, like 2, 4, 5, 6, and 8. This means that most students did very well on Q6.

# %%
print(df['Q6'].value_counts())
# Out:
# Q6
# 8.449134     51
# 10.000000    16
# 7.964286      3
# 9.000000      3
# 8.000000      3
# 6.484848      2
# 8.964286      2
# 6.964286      1
# 4.000000      1
# 2.000000      1
# 5.964286      1
# 6.000000      1
# 5.000000      1
# Name: count, dtype: int64

# %% [markdown]
# # From above histograms the students scored max marks in Q1 & Q2 so while preparing the question paper for the next time these questions are not prefered to be added in order to increse the difficulty level of the paper

# %%
df[['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']].sum().plot(kind='pie',autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart of Sum of the Values for Q1 to Q6")
plt.show()

# %% [markdown]
# # From the above pie chart we can deduce that Q2 (24.7%) and Q1 (24.4%) are the largest contributors, holding almost 50% shares of the total. Q5 (18.4%) and Q3 (16.4%) are average sized, Q6 (9.3%) is smaller and Q4 (6.8%) is the smallest.Q2 is the largest & Q4 is smallest.

# %%
df[['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']].max().plot(kind='pie', figsize=(8, 8), autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart of max Values for Q1 to Q6")
plt.show()

# %% [markdown]
# # From the above pie chart we can deduce that all Questions have same maximum values i.e. same Maximum marks, each holding 16.7% of the total.

# %%
df[['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']].min().plot(kind='pie', figsize=(8, 8), autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart of Minimum Values for Q1 to Q6")
plt.show()

# %% [markdown]
# # The pie chart shows that Q1 and Q5 are highest scored among all other questions with 23.5% each , Q2 is average scored with 17.6%, while Q3, Q4, and Q6 are the least scored among all other questions with 11.8% each.

# %%
a=df.loc[(df['Total'] >= 35) & (df['Total'] <= 40)]
a=a.reset_index()
a
# Out:
#     index  Total    Q5         Q1         Q2         Q3         Q4         Q6
# 0       0     37   8.0   9.000000  10.000000   3.000000   7.468750  10.000000
# 1       4     36  10.0   9.000000   8.000000   9.000000   7.353365   8.449134
# 2       9     35   8.0   6.000000   9.000000  10.000000   7.353365  10.000000
# 3      10     37   8.0   8.000000  10.000000   8.271116   9.000000  10.000000
# 4      17     36   9.0   7.000000  10.000000   8.271116   7.353365  10.000000
# 5      26     39   8.0  10.000000   9.000000   8.098039   7.353365  10.000000
# 6      28     38  10.0   8.000000  10.000000  10.000000   7.353365   8.449134
# 7      33     40   8.0   8.113779  10.000000  10.000000  10.000000  10.000000
# 8      36     37  10.0   6.972603  10.000000  10.000000   7.353365   9.000000
# 9      42     38   8.0  10.000000  10.000000  10.000000   8.000000   8.449134
# 10     44     36  10.0   9.000000   8.000000   8.271116   9.000000   8.449134
# ...

# %% [markdown]
# # Total marks 35-40 is filtered from the data set

# %%
a.plot.scatter(x='Q1',y='Total',color='red',s=40)
plt.title("35-40 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # Majority of the students in this range scored marks between 8-10 in Q1 and very few, just 2 students scored below 7 marks, maximum mark scored is 10 by five students

# %%
a.plot.scatter(x='Q2',y='Total',color='pink',s=40)
plt.title("35-40 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # Some students have not attempted this question whereas those who have attempted scored marks between 8 and 10 overall. Maximum mark is 10 scored by 6 students.

# %%
a.plot.scatter(x='Q3',y='Total',color='green',s=40)
plt.title("35-40 Marks ANALYSIS")
plt.show()

# %% [markdown]
#  # Majority of the students who attempted Q3 in this range scored 9 & 10 marks & minimum mark is 3 scored by one student.

# %%
a.plot.scatter(x='Q4',y='Total',color='blue',s=40)
plt.title("35-40 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # Most of the students in this range haven't attempted this question, others got 8-10 marks and maximum mark is 10 by three students.

# %%
a.plot.scatter(x='Q5',y='Total',color='purple',s=40)
plt.title("35-40 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # Majority of the students who attempted scored marksbetween 8 and 10, also some scored below 8,Maximum mark is 10 scored by five students and Minimum mark is 5 scored by one student

# %%
a.plot.scatter(x='Q6',y='Total',color='yellow',s=40)
plt.title("35-40 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # Majority of the students have not attempted this question whereas those who have attempted scored good marks. Maximum mark is 10 scored by six students and minimun mark scored is 9 scored by one student.

# %%
b=df.loc[(df['Total'] >= 15) & (df['Total'] <= 20)]
b=b.reset_index()
b
# Out:
#    index  Total   Q5         Q1         Q2        Q3         Q4        Q6
# 0      5     20  8.0  10.000000  10.000000  8.271116   7.353365  8.449134
# 1     30     20  8.0   8.000000   8.000000  9.098039   7.353365  8.449134
# 2     34     19  5.0   5.000000   4.000000  5.000000   7.353365  8.449134
# 3     57     17  8.0   7.972603   9.291667  8.271116  10.000000  8.964286
# 4     60     20  8.0   7.000000   5.000000  8.271116   7.353365  8.449134
# 5     63     18  8.0   8.972603   6.000000  8.271116   7.353365  8.449134
# 6     68     20  8.0  10.000000  10.000000  8.271116   7.353365  8.449134
# 7     76     17  8.0   5.000000   6.000000  6.000000   7.353365  8.449134

# %% [markdown]
# # Total marks 15-20 is filtered from the data set

# %%
a.boxplot(by='Q5', column =['Total'], grid = False,color='blue')
plt.title("35-40 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Half of the students in this range got marks between 7 and 10, the maximum mark is 10 and minimum mark is 5.

# %%
b.boxplot(by='Q2', column =['Total'], grid = False,color='yellow',figsize=[5,6])
plt.title("15-20 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Majority of the students who attempted the question in this range scored marks between 6 and 10 The maximum mark is 10 whereas minimum mark is 4.

# %%
b.boxplot(by='Q3', column =['Total'], grid = False,color='green',figsize=[5,6])
plt.title("15-20 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # only two sudents attempted the question in this range where the minimum mark  is 5 and maximum mark is 6.

# %%
b.boxplot(by='Q4', column =['Total'], grid = False,color='blue',figsize=[5,6])
plt.title("15-20 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # only one sudent attempted the question in this range & scored 10 marks

# %%
b.boxplot(by='Q5', column =['Total'], grid = False,color='orange',figsize=[5,6])
plt.title("15-20 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # only three sudents attempted the question in this range where the majority of the students scored 8 marks ie 2 students whereas remaining 1 student scored 5 marks

# %% [markdown]
# # No student have attempted the Q6 so we cannot plot for Q6

# %%
c=df.loc[(df['Total']>=25) & (df['Total']<=30)]
c=c.reset_index()
c
# Out:
#     index  Total    Q5         Q1         Q2         Q3         Q4        Q6
# 0       6     25   6.0   7.000000   7.291667  10.000000   7.353365  8.449134
# 1       8     27   9.0   8.000000   8.200000   8.271116   7.353365  7.964286
# 2      14     30   8.0  10.000000   8.000000   9.000000   7.884615  8.449134
# 3      16     30   8.0   8.972603  10.000000   7.000000   7.353365  8.449134
# 4      19     26   7.0   7.972603  10.000000   6.173077   3.000000  7.964286
# 5      20     29   7.0   8.000000   4.000000  10.000000   7.353365  8.449134
# 6      29     27   8.0   8.972603   7.000000   8.271116   9.468750  9.000000
# 7      31     26   8.0   7.000000   8.000000   6.098039   5.884615  8.000000
# 8      35     30   8.0  10.000000  10.000000   5.173077   7.353365  8.449134
# 9      38     28   8.0   9.000000  10.000000   8.000000   5.884615  5.964286
# 10     40     29   7.0  10.000000  10.000000   8.271116   2.000000  8.449134
# ...

# %% [markdown]
# # Total marks 25-30 is filtered from the data set

# %%
a.plot.line(x='Q6',y='Total',color='purple')
plt.title("Line Graph of Q1")
plt.ylabel("Total")
plt.show()

# %% [markdown]
#  # It can be deduced from the above line graph that majority of the students in this range scored marks between 8 and 10. The maximum mark is 10 and minimum mark is 4.

# %%
a.plot.line(x='Q3',y='Total',color='green')
plt.title("Line Graph of Q3")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # The students who attempted this question scored marks between 8 and 10 overall, also the minimum  mark is four whereas the maximum mark is 10.

# %%
c_clean = c.dropna(subset=['Q3', 'Total'])
c_clean.plot.line(x='Q3', y='Total', color='orange')
plt.title("Line Graph of Q3")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # The students in this range maximum mark is 10 scored by two students whereas minimum mark is 7 scored by three students.

# %%
c_clean = c.dropna(subset=['Q4', 'Total'])
c_clean.plot.line(x='Q4', y='Total', color='purple')
plt.title("Line Graph of Q4")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Most of the students who have attempted the question scored marks between 8 and 10 on an average. The minimum mark for the question is 2 whereas highest mark scored is 10

# %%
c.plot.line(x='Q5',y='Total',color='yellow')
plt.title("Line Graph of Q5")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Majority of the students who attempted this question scored marks between 6 and 9 overall.The maximum mark is 10 whereas minimum mark is 4, meaning some students left the question unattempted.

# %%
c_clean = c.dropna(subset=['Q6', 'Total'])
c_clean.plot.line(x='Q6', y='Total', color='green')
plt.title("Line Graph of Q6")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # only some of the students have attempted this question and scored marks in between 5 & 9 overall.The maximum mark is 9 where as the minimum mark is 5

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.barplot(x=df.index, y="Total", data=df, palette="viridis")
plt.title("Total Scores of Students")
plt.xlabel("Student Index")
plt.ylabel("Total Score")
plt.show()
# Out:
# C:\Users\ashuk\AppData\Local\Temp\ipykernel_25988\1419391769.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df.index, y="Total", data=df, palette="viridis")

# %% [markdown]
# ## The bar plot displays the total scores of students, with each bar representing an individual student's total score.

# %%
sns.countplot(x=df["Q5"])
plt.show()

# %% [markdown]
# # The majority of the students those who have attempted this question have scored marks in between 7 & 10

# %%
sns.histplot(df["Total"], kde=True, bins=9, color="orange")
plt.title("Distribution of Total Scores")
plt.xlabel("Total Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The histogram with a KDE curve shows the distribution of total scores, providing insights into the frequency of different score ranges. The shape of the curve helps identify whether the scores are normally distributed or skewed¶

# %%
sns.boxplot(data=df.iloc[:, 1:])
plt.title("Score Distribution Across Questions")
plt.xlabel("Questions")
plt.ylabel("Scores")
plt.show()

# %% [markdown]
# The boxplot shows the distribution of scores across different questions, with each box representing a question's score spread.

# %%
df[['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']].mean().plot(kind='pie', figsize=(8, 8), autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart of Mean Values for Q1 to Q6")
plt.show()

# %% [markdown]
# The above pie chart displays the percentage for the mean values of all the questions present in the data set where Q6 is the most dominant category(17.7%), while Q4 is the least(15.3). Q2 and Q3 are also notable, making up a large portion of the total , Q1(16.5%) and Q5(16.1%) are Middle-sized pieces.

# %% [markdown]
# ## Observations from Data Analysis
#
# ### Column Renaming:
# - Some columns had complex names like `Q1aM4`, `Q1bM6`, etc. They might need renaming for better readability.
#
# ### Data Type Conversions:
# - The dataset contained a mix of `int64` and `float64` values.
# - All marks were converted to integers for better analysis.
#
# ### General Performance Trend:
# - Most students scored **above 80%**, indicating strong performance.
# - A few students had significantly lower scores, indicating struggles in some subjects.
#
# ### Subject-Wise Performance:
# - **Q1**: Most students scored **8-10 marks**, with 19 students scoring a perfect **10**.
# - **Q2**: 34 students scored **10 marks**, while others had scores distributed between **4-9**.
# - **Q3**: Scores were more spread out, with **30 students around 8.27** and **27 students scoring 10**.
# - **Q4**: A majority scored **7.35**, with some scoring **10 or below 6**.
#
# ### Pie Chart Analysis:
# - Some sections contributed **more to total marks**, while others had **lower impact**.
# - **Q1 and Q2 had higher weightage**, while **Q3 and Q4 were more variable**.
#
# ### Correlation Analysis:
# - Some sections showed a **strong correlation with total marks**, while others had weaker links.
# - Further breakdown could reveal if any subject was particularly challenging.
#
# ### High Scorers (Near Maximum Marks):
# - Many students had **consistent high scores (8-10 marks in all sections)**.
# - Some subjects had **multiple students scoring full marks**.
#
# ### Low Scorers (Below 50%):
# - Students scoring **below 6** in multiple sections tended to have an overall low total.
# - These students struggled particularly in **Q3 and Q4**.
#
# ### Final Observations & Recommendations:
# - **Q1 and Q2 seem easier**, with more high scores.
# - **Q3 and Q4 have more variance**, suggesting they may be harder for some students.
# - Further analysis could be done to see if **certain question types or topics** were more difficult.
#
# ### Performance Groups:
# - **Top Performers**: Consistently scored **8+ in all sections**.
# - **Struggling Students**: Had **low scores (below 6) in Q3 and Q4**.
